# %%
import folium
import pandas as pd
from pymongo import MongoClient
from IPython.display import display


# Connect to database
try:
    client = MongoClient('mongodb://localhost:27017/')
    print('Connection successful.')
except:
    print('Could not connect to MongoDB')
    exit()

db = client.requests  # Database
collection = db.sr    # Collection within database
projection = {'_id': False, 'Latitude': True, 'Longitude': True, 'Agency': True}  # Properties we want.
coordinates = collection.find({'Agency': 'NYPD'}, projection)[:100]
print('Successfully obtained coordinates.')

hc_coords = (40.768890, -73.964789)

# Create empty map zoomed in on Hunter College
map_1 = folium.Map(location=hc_coords, zoom_start=10)

print('Inserting points.')
for each in coordinates:
    if each['Latitude'] and each['Longitude']:
        print('{} {} {}'.format(each['Agency'], each['Latitude'], each['Longitude']))
        folium.CircleMarker([each['Latitude'], each['Longitude']], radius=1).add_to(map_1)

print('Displaying points on map_1.')
map_1.save('map1.html')
# Out:
# Connection successful.
# Successfully obtained coordinates.
# Inserting points.
# NYPD 40.70182309943841 -73.98284003196223
# NYPD 40.87556453341452 -73.88611123391182
# NYPD 40.745728207655894 -73.88621048623587
# NYPD 40.63606492388788 -73.89630573042852
# NYPD 40.80520120189394 -73.95314677412019
# NYPD 40.83811767058312 -73.9448368284078
# NYPD 40.675651511986466 -73.9110036136785
# NYPD 40.896395792492356 -73.89680027435357
# NYPD 40.784869028449954 -73.9485461604263
# NYPD 40.713198496024376 -73.87413871579652
# NYPD 40.656855438042214 -73.95312121435825
# NYPD 40.75894563555228 -73.86011542348267
# NYPD 40.63583084691343 -73.98590152326082
# NYPD 40.808352974005636 -73.94281692202091
# NYPD 40.66883440348891 -73.94845543554169
# NYPD 40.60835039753288 -74.01032910481905
# NYPD 40.75645038025083 -73.89025647952307
# NYPD 40.67910952008634 -73.94005790714336
# NYPD 40.683044837854396 -73.95012102555529
# NYPD 40.623949010841265 -74.01081783506336
# NYPD 40.62874966702916 -73.97272470140605
# NYPD 40.5985014447795 -74.0884326297098
# NYPD 40.863886631078344 -73.88974296020218
# NYPD 40.61176844745842 -73.97637294363797
# NYPD 40.79862370810118 -73.96550374417566
# NYPD 40.81741161747582 -73.90006229643517
# NYPD 40.81265969749149 -73.94332981742318
# NYPD 40.70630593173905 -73.91957571461724
# NYPD 40.62874966702916 -73.97272470140605
# NYPD 40.71397415162171 -73.94119528888764
# NYPD 40.87303474844359 -73.90195294442927
# NYPD 40.675651511986466 -73.9110036136785
# NYPD 40.86387479538676 -73.85873780112755
# NYPD 40.808352974005636 -73.94281692202091
# NYPD 40.827697193673266 -73.83052546308947
# NYPD 40.74337596142075 -73.75950926531158
# NYPD 40.859131610744114 -73.90050210205231
# NYPD 40.71271235686723 -73.98927597325894
# NYPD 40.78440378776013 -73.7992738484293
